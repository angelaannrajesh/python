# %%
instruction = "Here's how you play the risk game. When you start the game, you get a number, which is from 1 - 7, and the computer chooses a number; it doesn't know what number you got, so there is no cheating, but you can choose whether to roll again one more time if your number is really low, it's not guaranteed you'll get a higher number, so be wise and take risks, there will be questions during the game, so don't get frustrated if you don't understand the instructions."
name = input("Please enter your name: ")
print("Hi, It's nice to meet you. I will guide you through this game")
q = input("Type yes if you wish to proceed...")
print("_______________________________________________________________________________________________________________________________")
if q == "yes":
    print(instruction)
    print("_______________________________________________________________________________________________________________________________")
else:
    print('Ok...')
lose = """
BAM...You Lose !
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
\\\\\\\\\\\\\
"""
win = """
Here's A Handshake ... For Winning !!!
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
"""
tie = """
IT'S A TIE...RESTART!
    _______              ________
---'   ____)_____   _____(____   '---
          ______)   (______
       __________) (__________
      (____)            (____)
---.__(___)              (___)__.---
       """
import random
firstroll = random.randint(1,6)
secondroll = random.randint(1,6)
computer = random.randint(1,6)
answer = input(f"Your number is {firstroll}, Would you like to roll again? Click yes if you do or click no if you don't. : ")
print("OK, Please wait... Loading")

b = input("Before you get your results, please enter wether this is your FirstRoll or SecondRoll: ")
print("                                        ")
print(f"Computer's number is {computer}: ")
if answer == "yes":
    print(f"Your new number is {secondroll}")
if computer < firstroll and b == "FirstRoll":
    print("You Win")
    print(win)
if  computer < secondroll and b == "SecondRoll":
    print("You Win")
    print(win)
elif computer == firstroll and b == "FirstRoll":
    print("It's a Tie")
    print(tie)
elif computer == secondroll and b == "SecondRoll":
    print("It's a Tie")
    print(tie)
elif computer > firstroll and b == "FirstRoll":
    print("Computer Wins")
    print(lose)
elif computer > secondroll and b == "SecondRoll":
    print("Computer Wins")
    print(lose)
elif answer == "no":
    print(f"Computer's number is {computer}: ")
else :
    print("Please read instructions and enter yes or no.")

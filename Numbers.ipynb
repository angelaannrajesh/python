# %%
2 + 2
# Out:
# 4

# %%
3-1
# Out:
# 2

# %%
4 * 5
# Out:
# 20

# %%
2 ** 3
# Out:
# 8

# %%
12 % 4
# Out:
# 0

# %%
12 / 4
# Out:
# 3.0

# %%
a = 12

# %%
a + a
# Out:
# 24

# %%
a * a
# Out:
# 144

# %%
a = 1435

# %%
b = 238930

# %%
a ** b
# Out:
# ...

# %%
a
# Out:
# 1435

# %%
32085 * 20485
# Out:
# 657261225

# %%
a + b
# Out:
# 240365

# %%
# Out:
#   File "<ipython-input-24-e93e740655b8>", line 1
#     12 $ 4
#        ^
# SyntaxError: invalid syntax
